# %%
import cv2
import matplotlib.pyplot as plt

# %%
pic1=cv2.imread('aa.jpg',1)
pic2=cv2.imread('aa.jpg',0)

# %%
pic1

# %%
pic1.shape
# Out:
# (2592, 1944, 3)

# %%
plt.imshow(pic1)
#plt.imshow(pic2)

# %%
plt.imshow(pic2)

# %%
newpic1=pic1-50

# %%
plt.imshow(newpic1)

# %%
newpic1=pic1+100
plt.imshow(newpic1)

# %%
newpic1=pic1+150
plt.imshow(newpic1)

# %%
croppic=pic1[:1200,:900]

# %%
plt.imshow(croppic)

# %%
x,y,z=cv2.split(pic1)

# %%
plt.imshow(x)

# %%
plt.imshow(y)

# %%
plt.imshow(z)

# %%
cv2.imwrite('bb.jpeg',pic1)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.destroyAllWindows()
