# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
read_image=cv2.imread('dd.jpeg')

# %%
read_image.shape
# Out:
# (452, 678, 3)

# %%
cv2_imshow(read_image)

# %%
a=read_image[120:200,210:290]

# %%
scale=200
height=int(a.shape[0]*scale/100)
width=int(a.shape[1]*scale/100)
dim=(height,width)
new_image=cv2.resize(a,dim)
cv2_imshow(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F25A898E1D0>
