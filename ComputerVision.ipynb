# %%
import cv2

# %%
cv2.__version__  # checking version
# Out:
# '3.4.3'

# %%
img=cv2.imread('tiger.jpeg',0)  # to read image
img1=cv2.imread('tiger.jpeg',1)
img2=cv2.imread('tiger.jpeg',-1)

# %%
img
# Out:
# array([[ 82,  82,  82, ...,  90,  90,  90],
#        [ 80,  80,  80, ...,  90,  90,  90],
#        [ 79,  79,  79, ...,  90,  90,  90],
#        ...,
#        [175, 119, 116, ..., 132, 173, 118],
#        [136,  96,  88, ..., 124, 153, 102],
#        [158, 129, 152, ..., 134, 142, 110]], dtype=uint8)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (440, 660)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
plt.imshow(img1[150:220,300:450])

# %%
x,y,z=cv2.split(img1)

# %%
plt.imshow(x)

# %%
plt.imshow(y)

# %%
plt.imshow(z)

# %%
img

# %%
# Task1
# image operation
#1) image compression
#2) image decompression

# Task2
# zoom a spot
# zoom every part except of that spot
