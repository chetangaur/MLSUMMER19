# %%
import pandas as pd

# %%
read_bank=pd.read_csv('http://13.234.66.67/summer19/datasets/bank.csv')

# %%
read_bank
# Out:
#       RowNumber  CustomerId  ... EstimatedSalary  Exited
# 0             1    15634602  ...       101348.88       1
# 1             2    15647311  ...       112542.58       0
# 2             3    15619304  ...       113931.57       1
# 3             4    15701354  ...        93826.63       0
# 4             5    15737888  ...        79084.10       0
# 5             6    15574012  ...       149756.71       1
# 6             7    15592531  ...        10062.80       0
# 7             8    15656148  ...       119346.88       1
# 8             9    15792365  ...        74940.50       0
# 9            10    15592389  ...        71725.73       0
# 10           11    15767821  ...        80181.12       0
# 11           12    15737173  ...        76390.01       0
# 12           13    15632264  ...        26260.98       0
# 13           14    15691483  ...       190857.79       0
# 14           15    15600882  ...        65951.65       0
# ...

# %%
read_bank1=read_bank.head(30)

# %%
read_bank.shape
# Out:
# (10000, 14)

# %%
# modread_bank=read_bank1.drop('Surname',axis=1)

# %%
read_bank1
# Out:
#     RowNumber  CustomerId     Surname  ...  IsActiveMember EstimatedSalary Exited
# 0           1    15634602    Hargrave  ...               1       101348.88      1
# 1           2    15647311        Hill  ...               1       112542.58      0
# 2           3    15619304        Onio  ...               0       113931.57      1
# 3           4    15701354        Boni  ...               0        93826.63      0
# 4           5    15737888    Mitchell  ...               1        79084.10      0
# 5           6    15574012         Chu  ...               0       149756.71      1
# 6           7    15592531    Bartlett  ...               1        10062.80      0
# 7           8    15656148      Obinna  ...               0       119346.88      1
# 8           9    15792365          He  ...               1        74940.50      0
# 9          10    15592389          H?  ...               1        71725.73      0
# ...

# %%
read_bank2=read_bank1.head()
read_bank2
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
#for i in read_bank1[0,:]:
  read_bank1.plot.bar(x='CreditScore',y='Exited')

# %%
read_bank1.plot.bar(x='CreditScore',y='NumOfProducts')

# %%
read_bank1.plot.bar(x='Surname',y='EstimatedSalary')

# %%
import matplotlib.pyplot as plt

# Data to plot
Surname = read_bank2.iloc[:,2]
CreditScore =read_bank2.iloc[:,3]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','green']
explode = (0.1, 0, 0, 0,0)  # explode 1st slice

# Plot
plt.pie(CreditScore, explode=explode, labels=Surname, colors=colors,autopct='%1.1f%%')


plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
Surname = read_bank2.iloc[0:,2]
EstimatedSalary = read_bank2.iloc[0:,12]
explode=[0.1,0.1,0,0,0]

plt.pie(EstimatedSalary,labels=Surname,explode=explode,autopct='%1.1f%%')
#plt.axis()
plt.show()
